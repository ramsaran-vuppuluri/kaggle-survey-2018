# %% [markdown]
# # Employment
# ## Author: Ram Saran Vuppuluri

# %% [markdown]
# In this notebook we are analyzing Employment data gathered from survey takers.
#
# Instead of working on all the columns, we are going to extract the columns from multipleChoiceResponses.csv that are relevant to the analysis. (we are removing multipleChoiceResponses.csv data frame once the values are extracted from primary memory).
#
# Following questions in the survey are related to Employment:
#
# *	Q6--Select the title most similar to your current role (or most recent title if retired): - Selected Choice
# *	Q6_OTHER_TEXT--Select the title most similar to your current role (or most recent title if retired): - Other - Text
# *	Q7--In what industry is your current employer/contract (or your most recent employer if retired)? - Selected Choice
# *	Q7_OTHER_TEXT--In what industry is your current employer/contract (or your most recent employer if retired)? - Other - Text
# *	Q8--How many years of experience do you have in your current role?
# *	Q9--What is your current yearly compensation (approximate $USD)?
# *	Q10--Does your current employer incorporate machine learning methods into their business?
# *	Q11_Part_1--Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice - Analyze and understand data to influence product or business decisions
# *	Q11_Part_2--Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice - Build and/or run a machine learning service that operationally improves my product or workflows
# *	Q11_Part_3--Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice - Build and/or run the data infrastructure that my business uses for storing, analyzing, and operationalizing data
# *	Q11_Part_4--Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice - Build prototypes to explore applying machine learning to new areas
# *	Q11_Part_5--Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice - Do research that advances the state of the art of machine learning
# *	Q11_Part_6--Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice - None of these activities are an important part of my role at work
# *	Q11_Part_7--Select any activities that make up an important part of your role at work: (Select all that apply) - Selected Choice - Other
# *	Q11_OTHER_TEXT--Select any activities that make up an important part of your role at work: (Select all that apply) - Other - Text

# %%
import gc

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
multipleChoiceDF = pd.read_csv('../multipleChoiceResponses.csv',low_memory=False)

# %%
employmentDF = multipleChoiceDF[['Q6','Q7','Q8','Q9','Q10',]]

# %%
employmentDF.shape[0],multipleChoiceDF.shape[0]
# Out:
# (23860, 23860)

# %%
employmentDF.head()
# Out:
#                                                   Q6  \
# 0  Select the title most similar to your current ...
# 1                                         Consultant
# 2                                              Other
# 3                                     Data Scientist
# 4                                       Not employed
#
#                                                   Q7  \
# 0  In what industry is your current employer/cont...
# 1                                              Other
# 2                          Manufacturing/Fabrication
# 3                                     I am a student
# 4                                                NaN
#
#                                                   Q8  \
# 0  How many years of experience do you have in yo...
# 1                                                NaN
# 2                                               5-10
# 3                                                0-1
# 4                                                NaN
#
#                                                   Q9  \
# 0  What is your current yearly compensation (appr...
# 1                                                NaN
# 2                                          10-20,000
# 3                                           0-10,000
# 4                                                NaN
#
#                                                  Q10
# 0  Does your current employer incorporate machine...
# 1                                      I do not know
# 2                      No (we do not use ML methods)
# 3                                      I do not know
# 4                                                NaN

# %%
employmentDF.drop([0],inplace=True)
employmentDF.reset_index(drop=True,inplace=True)

# %%
employmentDF.head()
# Out:
#                Q6                         Q7    Q8         Q9  \
# 0      Consultant                      Other   NaN        NaN
# 1           Other  Manufacturing/Fabrication  5-10  10-20,000
# 2  Data Scientist             I am a student   0-1   0-10,000
# 3    Not employed                        NaN   NaN        NaN
# 4    Data Analyst             I am a student   0-1   0-10,000
#
#                              Q10
# 0                  I do not know
# 1  No (we do not use ML methods)
# 2                  I do not know
# 3                            NaN
# 4                  I do not know

# %%
employmentDF.rename(columns={"Q6":"Job_Title",
                             "Q7":"Industry",
                             "Q8":"Experience_In_Current_Role",
                             "Q9":"Annual_Compensation",
                             "Q10":"ML_In_Use"},inplace = True)

# %%
employmentDF.head()
# Out:
#         Job_Title                   Industry Experience_In_Current_Role  \
# 0      Consultant                      Other                        NaN
# 1           Other  Manufacturing/Fabrication                       5-10
# 2  Data Scientist             I am a student                        0-1
# 3    Not employed                        NaN                        NaN
# 4    Data Analyst             I am a student                        0-1
#
#   Annual_Compensation                      ML_In_Use
# 0                 NaN                  I do not know
# 1           10-20,000  No (we do not use ML methods)
# 2            0-10,000                  I do not know
# 3                 NaN                            NaN
# 4            0-10,000                  I do not know

# %%
sns.set(rc={'figure.figsize':(25,20)})
ax = sns.countplot(y = employmentDF.Job_Title)
plt.ylabel("Job Title")
ax.get_figure().savefig("Job Title.jpeg")
plt.show(ax);

# %%
sns.set(rc={'figure.figsize':(25,20)})
ax = sns.countplot(y = employmentDF.Industry)
plt.ylabel("Industry")
ax.get_figure().savefig("Industry.jpeg")
plt.show(ax);

# %%
employmentDF['Experience_In_Current_Role'] = employmentDF.Experience_In_Current_Role.fillna("0")

# %%
sns.set(rc={'figure.figsize':(25,20)})
ax = sns.countplot(y = employmentDF.Experience_In_Current_Role)
plt.ylabel("Experience In Current Role")
ax.get_figure().savefig("Experience In Current Role.jpeg")
plt.show(ax);

# %%
sns.set(rc={'figure.figsize':(25,20)})
ax = sns.countplot(y = employmentDF.Annual_Compensation)
plt.ylabel("Annual Compensation")
ax.get_figure().savefig("Annual Compensation.jpeg")
plt.show(ax);

# %%
sns.set(rc={'figure.figsize':(25,20)})
ax = sns.countplot(y = employmentDF.ML_In_Use)
plt.ylabel("ML In Use")
ax.get_figure().savefig("ML In Use.jpeg")
plt.show(ax);

# %%
employmentDF.to_csv("employment.csv",index=False)

# %%
del employmentDF
gc.collect()
# Out:
# 12028

# %%
roleDF = multipleChoiceDF[['Q11_Part_1','Q11_Part_2','Q11_Part_3','Q11_Part_4','Q11_Part_5','Q11_Part_6','Q11_Part_7']]

# %%
roleDF.shape[0],multipleChoiceDF.shape[0]
# Out:
# (23860, 23860)

# %%
del multipleChoiceDF
gc.collect()
# Out:
# 2411

# %%
roleDF.head()
# Out:
#                                           Q11_Part_1  \
# 0  Select any activities that make up an importan...
# 1  Analyze and understand data to influence produ...
# 2                                                NaN
# 3  Analyze and understand data to influence produ...
# 4                                                NaN
#
#                                           Q11_Part_2  \
# 0  Select any activities that make up an importan...
# 1  Build and/or run a machine learning service th...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q11_Part_3  \
# 0  Select any activities that make up an importan...
# 1  Build and/or run the data infrastructure that ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q11_Part_4  \
# 0  Select any activities that make up an importan...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q11_Part_5  \
# 0  Select any activities that make up an importan...
# 1  Do research that advances the state of the art...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q11_Part_6  \
# 0  Select any activities that make up an importan...
# 1                                                NaN
# 2  None of these activities are an important part...
# 3                                                NaN
# 4                                                NaN
#
#                                           Q11_Part_7
# 0  Select any activities that make up an importan...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
roleDF.drop([0],inplace=True)
roleDF.reset_index(drop=True,inplace=True)

# %%
roleDF.head()
# Out:
#                                           Q11_Part_1  \
# 0  Analyze and understand data to influence produ...
# 1                                                NaN
# 2  Analyze and understand data to influence produ...
# 3                                                NaN
# 4                                                NaN
#
#                                           Q11_Part_2  \
# 0  Build and/or run a machine learning service th...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q11_Part_3 Q11_Part_4  \
# 0  Build and/or run the data infrastructure that ...        NaN
# 1                                                NaN        NaN
# 2                                                NaN        NaN
# 3                                                NaN        NaN
# 4                                                NaN        NaN
#
#                                           Q11_Part_5  \
# 0  Do research that advances the state of the art...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q11_Part_6 Q11_Part_7
# 0                                                NaN        NaN
# 1  None of these activities are an important part...        NaN
# 2                                                NaN        NaN
# 3                                                NaN        NaN
# 4                                                NaN      Other

# %%
roleDF = pd.melt(roleDF)

# %%
roleDF.head()
# Out:
#      variable                                              value
# 0  Q11_Part_1  Analyze and understand data to influence produ...
# 1  Q11_Part_1                                                NaN
# 2  Q11_Part_1  Analyze and understand data to influence produ...
# 3  Q11_Part_1                                                NaN
# 4  Q11_Part_1                                                NaN

# %%
roleDF.drop(columns=['variable'],inplace=True)

# %%
roleDF.dropna(inplace=True)
roleDF.reset_index(drop=True,inplace=True)

# %%
roleDF.rename(columns={"value":"Role"},inplace=True)

# %%
sns.set(rc={'figure.figsize':(10,8)})
ax = sns.countplot(y = roleDF.Role)
plt.ylabel("Role")
ax.get_figure().savefig("Role.jpeg")
plt.show(ax);

# %%
roleDF.to_csv("role.csv",index=False)
