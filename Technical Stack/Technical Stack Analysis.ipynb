# %% [markdown]
# # Technical Stack
#
# ## Author: Ram Saran Vuppuluri

# %% [markdown]
# ### Introduction
#
# Kaggle had initiated an industry-wide survey in 2017 that presents a truly comprehensive view of the state of data science and machine learning. In 2018, the study was live for a week in October and had collected responses from 23,859 individuals.
#
# Data set used for the analysis is has 390+ columns. Not all columns are needed at any given point of the study. For this reason, the notebook is further divided into multiple subsections which will start with a business question, followed by data analysis. Only the columns that are related to the business question are extracted for analysis.
#
# Furthermore, we are persisting extracted columns into separate csv files that are utilized for generating visualizations using Tableau for Medium blog post.
#
# __One significant advantage with this approach is we are not ignoring the whole row if the respondent has not to answer specific questions. We are going to include all the answers (non-freeform) in the analysis.__
#
# In this notebook, we will analyze the Technical Stack of the survey takers.

# %%
import gc

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
def generate_vertical_countplot(x, xlabel='', figName=None, figSize=(8, 6)):
    '''
    This method will generate vertical Seaborn countplot.

    :param x: x parameter

    :param xlabel: x axis label

    :param figName: file name by which it need to be stored.

    :param figSize: plot figure size.

    :return: None
    '''
    sns.set(rc={'figure.figsize': figSize})

    ax = sns.countplot(x=x)

    plt.xlabel(xlabel)
    if figName != None:
        ax.get_figure().savefig(figName)
    plt.show(ax);

# %%
def generate_horizontal_countplot(y, ylabel='', figName=None, figSize=(12, 10)):
    '''
    This method will generate horizontal Seaborn countplot/

    :param y: y parameter

    :param ylabel: y axis label

    :param figName: file name by which it need to be stored

    :param figSize: plot figure size.

    :return: None
    '''
    sns.set(rc={'figure.figsize': figSize})

    ax = sns.countplot(y=y)

    plt.ylabel(ylabel)

    if figName != None:
        ax.get_figure().savefig(figName)
    plt.show(ax);

# %%
def generate_bar_plot(data, x, y, xlabel='', ylabel='', figName=None, figSize=(12, 10)):
    '''
    This method will generate Seaborn Bar plot.

    :param data: Pandas Dataframe.

    :param x: x parameter

    :param y: y parameter

    :param xlabel: x axis label

    :param ylabel: y axis label

    :param figName: file name by which it need to be stored

    :param figSize: plot figure size.

    :return: None
    '''
    sns.set(rc={'figure.figsize': figSize})
    ax = sns.barplot(x=x, y=y, data=data)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    ax.get_figure().savefig(figName)
    plt.show(ax);

# %%
multipleChoiceDF = pd.read_csv('../multipleChoiceResponses.csv',low_memory=False)

# %% [markdown]
# ### Which of the following integrated development environments (IDE's) have you used at work or school in the last 5 years?
# * __Jupyter/IPython__
# * __RStudio__
# * __PyCharm__
# * __Visual Studio Code__
# * __nteract__
# * __Atom__
# * __MATLAB__
# * __Visual Studio__
# * __Notepad++__
# * __Sublime Text__
# * __Vim__
# * __IntelliJ__
# * __Spyder__
# * __None__
# * __Other__

# %%
ideDF = multipleChoiceDF[['Q13_Part_1', 'Q13_Part_2','Q13_Part_3', 'Q13_Part_4','Q13_Part_5', 'Q13_Part_6',
                          'Q13_Part_7','Q13_Part_8','Q13_Part_9','Q13_Part_10','Q13_Part_11','Q13_Part_12',
                          'Q13_Part_13','Q13_Part_14','Q13_Part_15']]

# %%
ideDF.head()
# Out:
#                                           Q13_Part_1  \
# 0  Which of the following integrated development ...
# 1                                    Jupyter/IPython
# 2                                                NaN
# 3                                                NaN
# 4                                    Jupyter/IPython
#
#                                           Q13_Part_2  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                            RStudio
#
#                                           Q13_Part_3  \
# 0  Which of the following integrated development ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
ideDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23860 entries, 0 to 23859
# Data columns (total 15 columns):
# Q13_Part_1     14011 non-null object
# Q13_Part_2     8504 non-null object
# Q13_Part_3     7061 non-null object
# Q13_Part_4     5083 non-null object
# Q13_Part_5     128 non-null object
# Q13_Part_6     3907 non-null object
# Q13_Part_7     5672 non-null object
# Q13_Part_8     5112 non-null object
# Q13_Part_9     7832 non-null object
# Q13_Part_10    5986 non-null object
# Q13_Part_11    4241 non-null object
# Q13_Part_12    3457 non-null object
# Q13_Part_13    5340 non-null object
# Q13_Part_14    475 non-null object
# Q13_Part_15    1258 non-null object
# dtypes: object(15)
# memory usage: 2.7+ MB

# %% [markdown]
# From the visual and programmatic analysis:
# * There are rows with missing data, but deviating from data we explored till now, missing information is expected per record as selections are optional. We will melt into one single column removing missing values, and use this column for analysis.
# * All columns are loaded with the correct data type.
# * Row with ID 0, is the same as the question. We will drop this row from the analysis as it does not have any empirical value.
# * Column names are not informative, we will rename columns with more informative names.

# %%
ideDF.drop([0],inplace=True)
ideDF.reset_index(drop=True,inplace=True)

# %%
ideDF = pd.melt(ideDF)

# %%
ideDF.head()
# Out:
#      variable            value
# 0  Q13_Part_1  Jupyter/IPython
# 1  Q13_Part_1              NaN
# 2  Q13_Part_1              NaN
# 3  Q13_Part_1  Jupyter/IPython
# 4  Q13_Part_1              NaN

# %%
ideDF.drop(columns=['variable'],inplace=True)

# %%
ideDF.head()
# Out:
#              value
# 0  Jupyter/IPython
# 1              NaN
# 2              NaN
# 3  Jupyter/IPython
# 4              NaN

# %%
ideDF.dropna(inplace=True)
ideDF.reset_index(drop=True,inplace=True)

# %%
ideDF.head()
# Out:
#              value
# 0  Jupyter/IPython
# 1  Jupyter/IPython
# 2  Jupyter/IPython
# 3  Jupyter/IPython
# 4  Jupyter/IPython

# %% [markdown]
# __Every language has its syntax and semantics, and as humans, it’s not possible to memorize them. Integrated Development Environments (IDEs) are developed to avoid syntactical and semantical mistakes and increase productivity.__
#
# __Most of the businesses use IDEs for development. IDEs help to increase the overall productivity of developers.__

# %%
generate_horizontal_countplot(y=ideDF.value,
                             figSize=(10,8),
                             ylabel = 'IDE',
                             figName = 'ide.jpeg')

# %% [markdown]
# We will persist the clean copy of the dataframe as a CSV file.
#
# We no longer need "ideDF" in the analysis. We will clean up from memory.

# %%
ideDF.to_csv('ide.csv',index=False)

# %%
del ideDF
gc.collect()
# Out:
# 3613

# %% [markdown]
# ### Which of the following hosted notebooks have you used at work or school in the last 5 years?
# * __Kaggle Kernels__
# * __Google Colab__
# * __Azure Notebook__
# * __Domino Datalab__
# * __Google Cloud Datalab__
# * __Paperspace__
# * __Floydhub__
# * __Crestle__
# * __JupyterHub/Binder__
# * __None__
# * __Other__

# %%
notebookDF = multipleChoiceDF[['Q14_Part_1', 'Q14_Part_2','Q14_Part_3', 'Q14_Part_4','Q14_Part_5', 'Q14_Part_6',
                               'Q14_Part_7','Q14_Part_8','Q14_Part_9','Q14_Part_10','Q14_Part_11']]

# %%
notebookDF.head()
# Out:
#                                           Q14_Part_1  \
# 0  Which of the following hosted notebooks have y...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                     Kaggle Kernels
#
#                                           Q14_Part_2  \
# 0  Which of the following hosted notebooks have y...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                       Google Colab
#
#                                           Q14_Part_3  \
# 0  Which of the following hosted notebooks have y...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
notebookDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23860 entries, 0 to 23859
# Data columns (total 11 columns):
# Q14_Part_1     6043 non-null object
# Q14_Part_2     3533 non-null object
# Q14_Part_3     1305 non-null object
# Q14_Part_4     120 non-null object
# Q14_Part_5     1308 non-null object
# Q14_Part_6     481 non-null object
# Q14_Part_7     362 non-null object
# Q14_Part_8     139 non-null object
# Q14_Part_9     4917 non-null object
# Q14_Part_10    7598 non-null object
# Q14_Part_11    691 non-null object
# dtypes: object(11)
# memory usage: 2.0+ MB

# %% [markdown]
# From the visual and programmatic analysis:
# * There are rows with missing data, but deviating from data we explored till now, missing information is expected per record as selections are optional. We will melt into one single column removing missing values, and use this column for analysis.
# * All columns are loaded with the correct data type.
# * Row with ID 0, is the same as the question. We will drop this row from the analysis as it does not have any empirical value.
# * Column names are not informative, we will rename columns with more informative names.

# %%
notebookDF.drop([0],inplace=True)
notebookDF.reset_index(drop=True,inplace=True)

# %%
notebookDF.head()
# Out:
#        Q14_Part_1    Q14_Part_2      Q14_Part_3 Q14_Part_4 Q14_Part_5  \
# 0             NaN           NaN             NaN        NaN        NaN
# 1             NaN           NaN             NaN        NaN        NaN
# 2             NaN           NaN             NaN        NaN        NaN
# 3  Kaggle Kernels  Google Colab             NaN        NaN        NaN
# 4             NaN           NaN  Azure Notebook        NaN        NaN
#
#   Q14_Part_6 Q14_Part_7 Q14_Part_8 Q14_Part_9 Q14_Part_10 Q14_Part_11
# 0        NaN        NaN        NaN        NaN        None         NaN
# 1        NaN        NaN        NaN        NaN        None         NaN
# 2        NaN        NaN        NaN        NaN        None         NaN
# 3        NaN        NaN        NaN        NaN         NaN         NaN
# 4        NaN        NaN        NaN        NaN         NaN         NaN

# %%
notebookDF = pd.melt(notebookDF)

# %%
notebookDF.head()
# Out:
#      variable           value
# 0  Q14_Part_1             NaN
# 1  Q14_Part_1             NaN
# 2  Q14_Part_1             NaN
# 3  Q14_Part_1  Kaggle Kernels
# 4  Q14_Part_1             NaN

# %%
notebookDF.drop(columns=['variable'],inplace=True)

# %%
notebookDF.head()
# Out:
#             value
# 0             NaN
# 1             NaN
# 2             NaN
# 3  Kaggle Kernels
# 4             NaN

# %%
notebookDF.dropna(inplace=True)
notebookDF.reset_index(drop=True,inplace=True)

# %%
notebookDF.rename(columns={"value":"Notebook_kernel"},inplace=True)

# %% [markdown]
# __In the initial experimental phase of Data Science projects, Notebook Kernels provide an interactive environment for exploring, analyzing and conceptualizing data. Notebooks also provide an easy way to document and share findings in more than one format.__

# %%
generate_horizontal_countplot(y=notebookDF.Notebook_kernel,
                             figSize=(10,8),
                             ylabel = 'Notebook Kernel',
                             figName = 'notebook.jpeg')

# %% [markdown]
# We will persist the clean copy of the dataframe as a CSV file.
#
# We no longer need "notebookDF" in the analysis. We will clean up from memory.

# %%
notebookDF.to_csv('notebookDF.csv',index=False)

# %%
del notebookDF
gc.collect()
# Out:
# 3182

# %% [markdown]
# ### Which of the following cloud computing services have you used at work or school in the last 5 years?
# * __Google Cloud Platform (GCP)__
# * __Amazon Web Services (AWS)__
# * __Microsoft Azure__
# * __IBM Cloud__
# * __Alibaba Cloud__
# * __I have not used any cloud providers__
# * __Other__

# %%
cloudDF = multipleChoiceDF[['Q15_Part_1', 'Q15_Part_2','Q15_Part_3', 'Q15_Part_4','Q15_Part_5', 'Q15_Part_6',
                            'Q15_Part_7']]

# %%
cloudDF.head()
# Out:
#                                           Q15_Part_1  \
# 0  Which of the following cloud computing service...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                        Google Cloud Platform (GCP)
#
#                                           Q15_Part_2  \
# 0  Which of the following cloud computing service...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                          Amazon Web Services (AWS)
#
#                                           Q15_Part_3  \
# 0  Which of the following cloud computing service...
# 1                                    Microsoft Azure
# 2                                                NaN
# 3                                                NaN
# ...

# %%
cloudDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23860 entries, 0 to 23859
# Data columns (total 7 columns):
# Q15_Part_1    4784 non-null object
# Q15_Part_2    7461 non-null object
# Q15_Part_3    3806 non-null object
# Q15_Part_4    1205 non-null object
# Q15_Part_5    550 non-null object
# Q15_Part_6    7104 non-null object
# Q15_Part_7    777 non-null object
# dtypes: object(7)
# memory usage: 1.3+ MB

# %% [markdown]
# From the visual and programmatic analysis:
# * There are rows with missing data, but deviating from data we explored till now, missing information is expected per record as selections are optional. We will melt into one single column removing missing values, and use this column for analysis.
# * All columns are loaded with the correct data type.
# * Row with ID 0, is the same as the question. We will drop this row from the analysis as it does not have any empirical value.
# * Column names are not informative, we will rename columns with more informative names.

# %%
cloudDF.drop([0],inplace=True)

# %%
cloudDF.reset_index(drop=True,inplace=True)

# %%
cloudDF = pd.melt(cloudDF)

# %%
cloudDF.head()
# Out:
#      variable                        value
# 0  Q15_Part_1                          NaN
# 1  Q15_Part_1                          NaN
# 2  Q15_Part_1                          NaN
# 3  Q15_Part_1  Google Cloud Platform (GCP)
# 4  Q15_Part_1                          NaN

# %%
cloudDF.drop(columns=['variable'],inplace=True)

# %%
cloudDF.rename(columns={"value":"Cloud_Platform"},inplace=True)
cloudDF.dropna(inplace=True)
cloudDF.reset_index(drop=True,inplace=True)

# %%
cloudDF.head()
# Out:
#                 Cloud_Platform
# 0  Google Cloud Platform (GCP)
# 1  Google Cloud Platform (GCP)
# 2  Google Cloud Platform (GCP)
# 3  Google Cloud Platform (GCP)
# 4  Google Cloud Platform (GCP)

# %% [markdown]
# __Cloud platform provides storage and computing power on a shared network of servers. In theory, there should be no shortage of storage space & computational power.__

# %%
generate_vertical_countplot(x=cloudDF.Cloud_Platform,
                            xlabel="Cloud Platform",
                            figName='Cloud_Platform.jpeg',
                            figSize=(18,12))

# %% [markdown]
# We will persist the clean copy of the dataframe as a CSV file.
#
# We no longer need "cloudDF" in the analysis. We will clean up from memory.

# %%
cloudDF.to_csv('cloud.csv',index=False)

# %%
del cloudDF
gc.collect()
# Out:
# 2730

# %% [markdown]
# ### What programming languages do you use on a regular basis?
# * __Python__
# * __R__
# * __SQL__
# * __Bash__
# * __Java__
# * __Javascript/Typescript__
# * __Visual Basic/VBA__
# * __C/C++__
# * __MATLAB__
# * __Scala__
# * __Julia__
# * __Go__
# * __C#/.NET__
# * __PHP__
# * __Ruby__
# * __SAS/STATA__
# * __None__
# * __Other__

# %%
languageDF = multipleChoiceDF[['Q16_Part_1', 'Q16_Part_2','Q16_Part_3', 'Q16_Part_4','Q16_Part_5', 'Q16_Part_6',
                               'Q16_Part_7','Q16_Part_8','Q16_Part_9','Q16_Part_10','Q16_Part_11','Q16_Part_12',
                               'Q16_Part_13','Q16_Part_14','Q16_Part_15','Q16_Part_16','Q16_Part_17','Q16_Part_18']]

# %%
languageDF.head()
# Out:
#                                           Q16_Part_1  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                             Python
#
#                                           Q16_Part_2  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                NaN
# 3                                                  R
# 4                                                  R
#
#                                           Q16_Part_3  \
# 0  What programming languages do you use on a reg...
# 1                                                NaN
# 2                                                SQL
# 3                                                NaN
# ...

# %%
languageDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23860 entries, 0 to 23859
# Data columns (total 18 columns):
# Q16_Part_1     15712 non-null object
# Q16_Part_2     6686 non-null object
# Q16_Part_3     8268 non-null object
# Q16_Part_4     2709 non-null object
# Q16_Part_5     4000 non-null object
# Q16_Part_6     3250 non-null object
# Q16_Part_7     1275 non-null object
# Q16_Part_8     4384 non-null object
# Q16_Part_9     2653 non-null object
# Q16_Part_10    789 non-null object
# Q16_Part_11    231 non-null object
# Q16_Part_12    395 non-null object
# Q16_Part_13    1671 non-null object
# Q16_Part_14    1209 non-null object
# Q16_Part_15    343 non-null object
# Q16_Part_16    1053 non-null object
# Q16_Part_17    333 non-null object
# Q16_Part_18    625 non-null object
# dtypes: object(18)
# memory usage: 3.3+ MB

# %% [markdown]
# From the visual and programmatic analysis:
# * There are rows with missing data, but deviating from data we explored till now, missing information is expected per record as selections are optional. We will melt into one single column removing missing values, and use this column for analysis.
# * All columns are loaded with the correct data type.
# * Row with ID 0, is the same as the question. We will drop this row from the analysis as it does not have any empirical value.
# * Column names are not informative, we will rename columns with more informative names.

# %%
languageDF.drop([0],inplace=True)

# %%
languageDF.head()
# Out:
#   Q16_Part_1 Q16_Part_2 Q16_Part_3 Q16_Part_4 Q16_Part_5  \
# 1        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        SQL        NaN        NaN
# 3        NaN          R        NaN        NaN       Java
# 4     Python          R        SQL       Bash        NaN
# 5        NaN        NaN        SQL        NaN       Java
#
#               Q16_Part_6 Q16_Part_7 Q16_Part_8 Q16_Part_9 Q16_Part_10  \
# 1                    NaN        NaN        NaN        NaN         NaN
# 2                    NaN        NaN        NaN        NaN         NaN
# 3                    NaN        NaN        NaN     MATLAB         NaN
# 4  Javascript/Typescript        NaN        NaN        NaN         NaN
# 5                    NaN        NaN        NaN        NaN         NaN
#
#   Q16_Part_11 Q16_Part_12 Q16_Part_13 Q16_Part_14 Q16_Part_15 Q16_Part_16  \
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
languageDF.reset_index(drop=True,inplace=True)

# %%
languageDF = pd.melt(languageDF)

# %%
languageDF.head()
# Out:
#      variable   value
# 0  Q16_Part_1     NaN
# 1  Q16_Part_1     NaN
# 2  Q16_Part_1     NaN
# 3  Q16_Part_1  Python
# 4  Q16_Part_1     NaN

# %%
languageDF.drop(columns=['variable'],inplace=True)
languageDF.rename(columns={"value":"language"},inplace=True)
languageDF.dropna(inplace=True)
languageDF.reset_index(drop=True,inplace=True)

# %%
languageDF.head()
# Out:
#   language
# 0   Python
# 1   Python
# 2   Python
# 3   Python
# 4   Python

# %% [markdown]
# __An overwhelming number of respondents have suggested Python as the first programming language to learn.__

# %%
generate_horizontal_countplot(y=languageDF.language,
                             figSize=(10,8),
                             ylabel = 'Language',
                             figName = 'language.jpeg')

# %% [markdown]
# We will persist the clean copy of the dataframe as a CSV file.
#
# We no longer need "languageDF" in the analysis. We will clean up from memory.

# %%
languageDF.to_csv('language.csv',index=False)

# %%
del languageDF
gc.collect()
# Out:
# 4023

# %% [markdown]
# ### What specific programming language do you use most often?

# %%
frequentLanguageDF = pd.DataFrame(multipleChoiceDF.Q17)

# %%
frequentLanguageDF.head()
# Out:
#                                                  Q17
# 0  What specific programming language do you use ...
# 1                                                NaN
# 2                                                NaN
# 3                                               Java
# 4                                             Python

# %%
frequentLanguageDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23860 entries, 0 to 23859
# Data columns (total 1 columns):
# Q17    15223 non-null object
# dtypes: object(1)
# memory usage: 186.5+ KB

# %% [markdown]
# From the visual and programmatic analysis:
# * There are rows with missing data, we will not include these records in our report.
# * All columns are loaded with the correct data type.
# * Row with ID 0, is the same as the question. We will drop this row from the analysis as it does not have any empirical value.
# * Column names are not informative, we will rename columns with more informative names.

# %%
frequentLanguageDF.drop([0],inplace=True)
frequentLanguageDF.dropna(inplace=True)
frequentLanguageDF.reset_index(drop=True,inplace=True)

# %%
frequentLanguageDF.rename(columns={"Q17":"Frequent_Language"},inplace=True)

# %% [markdown]
# __An overwhelming number of respondents have suggested Python as the first programming language to learn.__

# %%
generate_horizontal_countplot(y=frequentLanguageDF.Frequent_Language,
                             figSize=(10,8),
                             ylabel = 'Frequent Language',
                             figName = 'Frequent Language.jpeg')

# %% [markdown]
# We will persist the clean copy of the dataframe as a CSV file.
#
# We no longer need "frequentLanguageDF" in the analysis. We will clean up from memory.

# %%
frequentLanguageDF.to_csv('frequentLanguage.csv',index=False)

# %%
del frequentLanguageDF
gc.collect()
# Out:
# 3908

# %% [markdown]
# ### What programming language would you recommend an aspiring data scientist to learn first?

# %%
firstLanguageDF = pd.DataFrame(multipleChoiceDF.Q18)

# %%
firstLanguageDF.head()
# Out:
#                                                  Q18
# 0  What programming language would you recommend ...
# 1                                             Python
# 2                                             Python
# 3                                             Python
# 4                                                SQL

# %%
firstLanguageDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23860 entries, 0 to 23859
# Data columns (total 1 columns):
# Q18    18789 non-null object
# dtypes: object(1)
# memory usage: 186.5+ KB

# %% [markdown]
# From the visual and programmatic analysis:
# * There are rows with missing data, we will not include these records in our report.
# * All columns are loaded with the correct data type.
# * Row with ID 0, is the same as the question. We will drop this row from the analysis as it does not have any empirical value.
# * Column names are not informative, we will rename columns with more informative names.

# %%
firstLanguageDF.drop([0],inplace=True)
firstLanguageDF.dropna(inplace=True)
firstLanguageDF.reset_index(drop=True,inplace=True)

# %%
firstLanguageDF.rename(columns={"Q18":"first_language"},inplace=True)

# %%
firstLanguageDF.head()
# Out:
#   first_language
# 0         Python
# 1         Python
# 2         Python
# 3            SQL
# 4              R

# %% [markdown]
# __An overwhelming number of respondents have suggested Python as the first programming language to learn.__

# %%
generate_horizontal_countplot(y=firstLanguageDF.first_language,
                             figSize=(10,8),
                             ylabel = 'First Language',
                             figName = 'First_language.jpeg')

# %%
firstLanguageDF.to_csv('firstLanguage.csv',index=False)

# %%
del firstLanguageDF
gc.collect()
# Out:
# 3386

# %% [markdown]
# ### What machine learning frameworks have you used in the past 5 years?
# * __Scikit-Learn__
# * __TensorFlow__
# * __Keras__
# * __PyTorch__
# * __Spark MLlib__
# * __H20__
# * __Fastai__
# * __Mxnet__
# * __Caret__
# * __Xgboost__
# * __mlr__
# * __Prophet__
# * __randomForest__
# * __lightgbm__
# * __catboost__
# * __CNTK__
# * __Caffe__
# * __None__
# * __Other__

# %%
mlDF = multipleChoiceDF[['Q19_Part_1', 'Q19_Part_2','Q19_Part_3', 'Q19_Part_4','Q19_Part_5', 'Q19_Part_6',
                         'Q19_Part_7','Q19_Part_8','Q19_Part_9','Q19_Part_10','Q19_Part_11','Q19_Part_12',
                         'Q19_Part_13','Q19_Part_14','Q19_Part_15','Q19_Part_16','Q19_Part_17','Q19_Part_18',
                         'Q19_Part_19']]

# %%
mlDF.head()
# Out:
#                                           Q19_Part_1  \
# 0  What machine learning frameworks have you used...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                       Scikit-Learn
#
#                                           Q19_Part_2  \
# 0  What machine learning frameworks have you used...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                         TensorFlow
#
#                                           Q19_Part_3  \
# 0  What machine learning frameworks have you used...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
mlDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23860 entries, 0 to 23859
# Data columns (total 19 columns):
# Q19_Part_1     12250 non-null object
# Q19_Part_2     9982 non-null object
# Q19_Part_3     8137 non-null object
# Q19_Part_4     3827 non-null object
# Q19_Part_5     2056 non-null object
# Q19_Part_6     1308 non-null object
# Q19_Part_7     1100 non-null object
# Q19_Part_8     595 non-null object
# Q19_Part_9     2221 non-null object
# Q19_Part_10    5572 non-null object
# Q19_Part_11    529 non-null object
# Q19_Part_12    733 non-null object
# Q19_Part_13    5968 non-null object
# Q19_Part_14    2100 non-null object
# Q19_Part_15    1038 non-null object
# Q19_Part_16    745 non-null object
# Q19_Part_17    1102 non-null object
# Q19_Part_18    2919 non-null object
# Q19_Part_19    537 non-null object
# dtypes: object(19)
# memory usage: 3.5+ MB

# %% [markdown]
# From the visual and programmatic analysis:
# * There are rows with missing data, but deviating from data we explored till now, missing information is expected per record as selections are optional. We will melt into one single column removing missing values, and use this column for analysis.
# * All columns are loaded with the correct data type.
# * Row with ID 0, is the same as the question. We will drop this row from the analysis as it does not have any empirical value.
# * Column names are not informative, we will rename columns with more informative names.

# %%
mlDF.drop([0],inplace=True)
mlDF.reset_index(drop=True,inplace=True)

# %%
mlDF = pd.melt(mlDF)

# %%
mlDF.head()
# Out:
#      variable         value
# 0  Q19_Part_1           NaN
# 1  Q19_Part_1           NaN
# 2  Q19_Part_1           NaN
# 3  Q19_Part_1  Scikit-Learn
# 4  Q19_Part_1           NaN

# %%
mlDF.drop(columns=['variable'],inplace=True)

# %%
mlDF.rename(columns={'value':'ML_Framework'},inplace=True)
mlDF.dropna(inplace=True)
mlDF.reset_index(drop=True,inplace=True)

# %%
mlDF.head()
# Out:
#    ML_Framework
# 0  Scikit-Learn
# 1  Scikit-Learn
# 2  Scikit-Learn
# 3  Scikit-Learn
# 4  Scikit-Learn

# %% [markdown]
# __Machine Learning frameworks provide an abstract implementation of Supervised, Unsupervised and Deep Learning algorithms. Not every framework provides all the algorithms.__

# %%
generate_horizontal_countplot(y=mlDF.ML_Framework,
                             figSize=(10,8),
                             ylabel = 'ML Framework',
                             figName = 'ML_Framework.jpeg')

# %% [markdown]
# We will persist the clean copy of the dataframe as a CSV file.
#
# We no longer need "mlDF" in the analysis. We will clean up from memory.

# %%
mlDF.to_csv('ML_Framework.csv',index=False)

# %%
del mlDF
gc.collect()
# Out:
# 4000

# %% [markdown]
# ### Of the choices that you selected in the previous question, which ML library have you used the most?

# %%
frequentMLDF = pd.DataFrame(multipleChoiceDF.Q20)

# %%
frequentMLDF.head()
# Out:
#                                                  Q20
# 0  Of the choices that you selected in the previo...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                       Scikit-Learn

# %%
frequentMLDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23860 entries, 0 to 23859
# Data columns (total 1 columns):
# Q20    12990 non-null object
# dtypes: object(1)
# memory usage: 186.5+ KB

# %% [markdown]
# From the visual and programmatic analysis:
# * There are rows with missing data, we will not include these records in our report.
# * All columns are loaded with the correct data type.
# * Row with ID 0, is the same as the question. We will drop this row from the analysis as it does not have any empirical value.
# * Column names are not informative, we will rename columns with more informative names.

# %%
frequentMLDF.drop([0],inplace=True)
frequentMLDF.dropna(inplace=True)
frequentMLDF.reset_index(inplace=True)

# %%
frequentMLDF.rename(columns={"Q20":"frequent_ml"},inplace=True)

# %%
generate_horizontal_countplot(y=frequentMLDF.frequent_ml,
                             figSize=(10,8),
                             ylabel = 'ML Framework',
                             figName = 'Frequent_ML_Framework.jpeg')

# %% [markdown]
# We will persist the clean copy of the dataframe as a CSV file.
#
# We no longer need "frequentMLDF" in the analysis. We will clean up from memory.

# %%
frequentMLDF.to_csv('frequentML.csv',index=False)

# %%
del frequentMLDF
gc.collect()
# Out:
# 3901

# %% [markdown]
# ### What data visualization libraries or tools have you used in the past 5 years?
#
# * __ggplot2__
# * __Matplotlib__
# * __Altair__
# * __Shiny__
# * __D3__
# * __Plotly__
# * __Bokeh__
# * __Seaborn__
# * __Geoplotlib__
# * __Leaflet__
# * __Lattice__
# * __None__
# * __Other__

# %%
visualizationDF = multipleChoiceDF[['Q21_Part_1', 'Q21_Part_2','Q21_Part_3', 'Q21_Part_4','Q21_Part_5', 'Q21_Part_6',
                                    'Q21_Part_7','Q21_Part_8','Q21_Part_9','Q21_Part_10','Q21_Part_11','Q21_Part_12',
                                    'Q21_Part_13']]

# %%
visualizationDF.head()
# Out:
#                                           Q21_Part_1  \
# 0  What data visualization libraries or tools hav...
# 1                                                NaN
# 2                                                NaN
# 3                                            ggplot2
# 4                                            ggplot2
#
#                                           Q21_Part_2  \
# 0  What data visualization libraries or tools hav...
# 1                                         Matplotlib
# 2                                                NaN
# 3                                         Matplotlib
# 4                                         Matplotlib
#
#                                           Q21_Part_3  \
# 0  What data visualization libraries or tools hav...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
visualizationDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23860 entries, 0 to 23859
# Data columns (total 13 columns):
# Q21_Part_1     7752 non-null object
# Q21_Part_2     13393 non-null object
# Q21_Part_3     220 non-null object
# Q21_Part_4     2629 non-null object
# Q21_Part_5     2220 non-null object
# Q21_Part_6     5598 non-null object
# Q21_Part_7     1908 non-null object
# Q21_Part_8     7776 non-null object
# Q21_Part_9     769 non-null object
# Q21_Part_10    1014 non-null object
# Q21_Part_11    873 non-null object
# Q21_Part_12    1922 non-null object
# Q21_Part_13    586 non-null object
# dtypes: object(13)
# memory usage: 2.4+ MB

# %% [markdown]
# From the visual and programmatic analysis:
# * There are rows with missing data, but deviating from data we explored till now, missing information is expected per record as selections are optional. We will melt into one single column removing missing values, and use this column for analysis.
# * All columns are loaded with the correct data type.
# * Row with ID 0, is the same as the question. We will drop this row from the analysis as it does not have any empirical value.
# * Column names are not informative, we will rename columns with more informative names.

# %%
visualizationDF.drop([0],inplace=True)

# %%
visualizationDF.reset_index(drop=True,inplace=True)

# %%
visualizationDF = pd.melt(visualizationDF)

# %%
visualizationDF.head()
# Out:
#      variable    value
# 0  Q21_Part_1      NaN
# 1  Q21_Part_1      NaN
# 2  Q21_Part_1  ggplot2
# 3  Q21_Part_1  ggplot2
# 4  Q21_Part_1      NaN

# %%
visualizationDF.drop(columns=['variable'],inplace=True)
visualizationDF.rename(columns={'value':'visualization_tool'},inplace=True)
visualizationDF.dropna(inplace=True)
visualizationDF.reset_index(drop=True,inplace=True)

# %%
visualizationDF.head()
# Out:
#   visualization_tool
# 0            ggplot2
# 1            ggplot2
# 2            ggplot2
# 3            ggplot2
# 4            ggplot2

# %%
generate_horizontal_countplot(y=visualizationDF.visualization_tool,
                             figSize=(10,8),
                             ylabel = 'Visualization Tool',
                             figName = 'visualization_tool.jpeg')

# %% [markdown]
# We will persist the clean copy of the dataframe as a CSV file.
#
# We no longer need "visualizationDF" in the analysis. We will clean up from memory.

# %%
visualizationDF.to_csv('visualization.csv',index=False)

# %%
del visualizationDF
gc.collect()
# Out:
# 3404

# %% [markdown]
# ### Which specific data visualization library or tool have you used the most?

# %%
frequentVisualizationDF = pd.DataFrame(multipleChoiceDF.Q22)

# %%
frequentVisualizationDF.head()
# Out:
#                                                  Q22
# 0  Of the choices that you selected in the previo...
# 1                                                NaN
# 2                                                NaN
# 3                                            ggplot2
# 4                                            ggplot2

# %%
frequentVisualizationDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23860 entries, 0 to 23859
# Data columns (total 1 columns):
# Q22    12185 non-null object
# dtypes: object(1)
# memory usage: 186.5+ KB

# %% [markdown]
# From the visual and programmatic analysis:
# * There are rows with missing data, we will not include these records in our report.
# * All columns are loaded with the correct data type.
# * Row with ID 0, is the same as the question. We will drop this row from the analysis as it does not have any empirical value.
# * Column names are not informative, we will rename columns with more informative names.

# %%
frequentVisualizationDF.drop([0],inplace=True)
frequentVisualizationDF.dropna(inplace=True)
frequentVisualizationDF.reset_index(drop=True,inplace=True)

# %%
frequentVisualizationDF.rename(columns={"Q22":"visualization_tool"},inplace=True)

# %%
generate_horizontal_countplot(y=frequentVisualizationDF.visualization_tool,
                             figSize=(10,8),
                             ylabel = 'Visualization Tool',
                             figName = 'frequent_visualization_tool.jpeg')

# %% [markdown]
# We will persist the clean copy of the dataframe as a CSV file.
#
# We no longer need "frequentVisualizationDF" in the analysis. We will clean up from memory.

# %%
frequentVisualizationDF.to_csv('frequentVisualization.csv',index=False)

# %%
del frequentVisualizationDF
gc.collect()
# Out:
# 3287

# %% [markdown]
# ### Which of the following cloud computing products have you used at work or school in the last 5 years?
#
# * __AWS Elastic Compute Cloud (EC2)__
# * __Google Compute Engine__
# * __AWS Elastic Beanstalk__
# * __Google App Engine__
# * __Google Kubernetes Engine__
# * __AWS Lambda__
# * __Google Cloud Functions__
# * __AWS Batch__
# * __Azure Virtual Machines__
# * __Azure Container Service__
# * __Azure Functions__
# * __Azure Event Grid__
# * __Azure Batch__
# * __Azure Kubernetes Service__
# * __IBM Cloud Virtual Servers__
# * __IBM Cloud Container Registry__
# * __IBM Cloud Kubernetes Service__
# * __IBM Cloud Foundry__
# * __None__
# * __Other__

# %%
cloudProductsDF = multipleChoiceDF[['Q27_Part_1', 'Q27_Part_2','Q27_Part_3', 'Q27_Part_4','Q27_Part_5', 'Q27_Part_6',
                                  'Q27_Part_7','Q27_Part_8','Q27_Part_9','Q27_Part_10','Q27_Part_11','Q27_Part_12',
                                  'Q27_Part_13','Q27_Part_14','Q27_Part_15','Q27_Part_16','Q27_Part_17','Q27_Part_18',
                                  'Q27_Part_19','Q27_Part_20']]

# %%
cloudProductsDF.head()
# Out:
#                                           Q27_Part_1  \
# 0  Which of the following cloud computing product...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q27_Part_2  \
# 0  Which of the following cloud computing product...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q27_Part_3  \
# 0  Which of the following cloud computing product...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
cloudProductsDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23860 entries, 0 to 23859
# Data columns (total 20 columns):
# Q27_Part_1     3873 non-null object
# Q27_Part_2     2206 non-null object
# Q27_Part_3     767 non-null object
# Q27_Part_4     1383 non-null object
# Q27_Part_5     617 non-null object
# Q27_Part_6     1692 non-null object
# Q27_Part_7     1200 non-null object
# Q27_Part_8     496 non-null object
# Q27_Part_9     1457 non-null object
# Q27_Part_10    473 non-null object
# Q27_Part_11    556 non-null object
# Q27_Part_12    120 non-null object
# Q27_Part_13    232 non-null object
# Q27_Part_14    237 non-null object
# Q27_Part_15    346 non-null object
# Q27_Part_16    165 non-null object
# Q27_Part_17    159 non-null object
# Q27_Part_18    323 non-null object
# Q27_Part_19    3377 non-null object
# Q27_Part_20    390 non-null object
# dtypes: object(20)
# memory usage: 3.6+ MB

# %% [markdown]
# From the visual and programmatic analysis:
# * There are rows with missing data, but deviating from data we explored till now, missing information is expected per record as selections are optional. We will melt into one single column removing missing values, and use this column for analysis.
# * All columns are loaded with the correct data type.
# * Row with ID 0, is the same as the question. We will drop this row from the analysis as it does not have any empirical value.
# * Column names are not informative, we will rename columns with more informative names.

# %%
cloudProductsDF.drop([0],inplace=True)
cloudProductsDF.reset_index(drop=True,inplace=True)

# %%
cloudProductsDF.head()
# Out:
#   Q27_Part_1 Q27_Part_2 Q27_Part_3 Q27_Part_4                Q27_Part_5  \
# 0        NaN        NaN        NaN        NaN                       NaN
# 1        NaN        NaN        NaN        NaN                       NaN
# 2        NaN        NaN        NaN        NaN                       NaN
# 3        NaN        NaN        NaN        NaN                       NaN
# 4        NaN        NaN        NaN        NaN  Google Kubernetes Engine
#
#   Q27_Part_6 Q27_Part_7 Q27_Part_8 Q27_Part_9 Q27_Part_10 Q27_Part_11  \
# 0        NaN        NaN        NaN        NaN         NaN         NaN
# 1        NaN        NaN        NaN        NaN         NaN         NaN
# 2        NaN        NaN        NaN        NaN         NaN         NaN
# 3        NaN        NaN        NaN        NaN         NaN         NaN
# 4        NaN        NaN        NaN        NaN         NaN         NaN
#
#   Q27_Part_12 Q27_Part_13 Q27_Part_14 Q27_Part_15 Q27_Part_16 Q27_Part_17  \
# ...

# %%
cloudProductsDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23859 entries, 0 to 23858
# Data columns (total 20 columns):
# Q27_Part_1     3872 non-null object
# Q27_Part_2     2205 non-null object
# Q27_Part_3     766 non-null object
# Q27_Part_4     1382 non-null object
# Q27_Part_5     616 non-null object
# Q27_Part_6     1691 non-null object
# Q27_Part_7     1199 non-null object
# Q27_Part_8     495 non-null object
# Q27_Part_9     1456 non-null object
# Q27_Part_10    472 non-null object
# Q27_Part_11    555 non-null object
# Q27_Part_12    119 non-null object
# Q27_Part_13    231 non-null object
# Q27_Part_14    236 non-null object
# Q27_Part_15    345 non-null object
# Q27_Part_16    164 non-null object
# Q27_Part_17    158 non-null object
# Q27_Part_18    322 non-null object
# Q27_Part_19    3376 non-null object
# Q27_Part_20    389 non-null object
# dtypes: object(20)
# memory usage: 3.6+ MB

# %%
cloudProductsDF = pd.melt(cloudProductsDF)

# %%
cloudProductsDF.head()
# Out:
#      variable value
# 0  Q27_Part_1   NaN
# 1  Q27_Part_1   NaN
# 2  Q27_Part_1   NaN
# 3  Q27_Part_1   NaN
# 4  Q27_Part_1   NaN

# %%
cloudProductsDF.drop(columns=['variable'],inplace=True)

# %%
cloudProductsDF.head()
# Out:
#   value
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
cloudProductsDF.dropna(inplace=True)
cloudProductsDF.reset_index(drop=True,inplace=True)

# %%
cloudProductsDF.head()
# Out:
#                              value
# 0  AWS Elastic Compute Cloud (EC2)
# 1  AWS Elastic Compute Cloud (EC2)
# 2  AWS Elastic Compute Cloud (EC2)
# 3  AWS Elastic Compute Cloud (EC2)
# 4  AWS Elastic Compute Cloud (EC2)

# %%
cloudProductsDF.rename(columns={"value":"cloudProducts"},inplace=True)

# %%
generate_horizontal_countplot(y=cloudProductsDF.cloudProducts,
                             ylabel = 'Cloud Products',
                             figName = 'cloudProducts.jpeg')

# %% [markdown]
# We will persist the clean copy of the dataframe as a CSV file.
#
# We no longer need "cloudProductsDF" in the analysis. We will clean up from memory.

# %%
cloudProductsDF.to_csv('cloudProducts.csv',index=False)

# %%
del cloudProductsDF
gc.collect()
# Out:
# 4435

# %% [markdown]
# ### Which of the following machine learning products have you used at work or school in the last 5 years?
# * __Amazon Transcribe__
# * __Google Cloud Speech-to-text API__
# * __Amazon Rekognition__
# * __Google Cloud Vision API__
# * __Amazon Comprehend__
# * __Google Cloud Natural Language API__
# * __Amazon Translate__
# * __Google Cloud Translation API__
# * __Amazon Lex__
# * __Google Dialogflow Enterprise Edition__
# * __Amazon Rekognition Video__
# * __Google Cloud Video Intelligence API__
# * __Google Cloud AutoML__
# * __Amazon SageMaker__
# * __Google Cloud Machine Learning Engine__
# * __DataRobot__
# * __H20 Driverless AI__
# * __Domino Datalab__
# * __SAS__
# * __Dataiku__
# * __RapidMiner__
# * __Instabase__
# * __Algorithmia__
# * __Dataversity__
# * __Cloudera__
# * __Azure Machine Learning Studio__
# * __Azure Machine Learning Workbench__
# * __Azure Cortana Intelligence Suite__
# * __Azure Bing Speech API__
# * __Azure Speaker Recognition API__
# * __Azure Computer Vision API__
# * __Azure Face API__
# * __Azure Video API__
# * __IBM Watson Studio__
# * __IBM Watson Knowledge Catalog__
# * __IBM Watson Assistant__
# * __IBM Watson Discovery__
# * __IBM Watson Text to Speech__
# * __IBM Watson Visual Recognition__
# * __IBM Watson Machine Learning__
# * __Azure Cognitive Services__
# * __None__
# * __Other__

# %%
mlProductsDF = multipleChoiceDF[['Q28_Part_1', 'Q28_Part_2','Q28_Part_3', 'Q28_Part_4','Q28_Part_5', 'Q28_Part_6',
                                 'Q28_Part_7','Q28_Part_8','Q28_Part_9','Q28_Part_10','Q28_Part_11','Q28_Part_12',
                                 'Q28_Part_13','Q28_Part_14','Q28_Part_15','Q28_Part_16','Q28_Part_17','Q28_Part_18',
                                 'Q28_Part_19','Q28_Part_20','Q28_Part_21', 'Q28_Part_22','Q28_Part_23', 'Q28_Part_24',
                                 'Q28_Part_25', 'Q28_Part_26','Q28_Part_27','Q28_Part_28','Q28_Part_29','Q28_Part_30',
                                 'Q28_Part_31','Q28_Part_32','Q28_Part_33','Q28_Part_34','Q28_Part_35','Q28_Part_36',
                                 'Q28_Part_37','Q28_Part_38','Q28_Part_39','Q28_Part_40','Q28_Part_41','Q28_Part_42',
                                 'Q28_Part_43']]

# %%
mlProductsDF.head()
# Out:
#                                           Q28_Part_1  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q28_Part_2  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q28_Part_3  \
# 0  Which of the following machine learning produc...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
mlProductsDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23860 entries, 0 to 23859
# Data columns (total 43 columns):
# Q28_Part_1     119 non-null object
# Q28_Part_2     625 non-null object
# Q28_Part_3     300 non-null object
# Q28_Part_4     665 non-null object
# Q28_Part_5     133 non-null object
# Q28_Part_6     623 non-null object
# Q28_Part_7     161 non-null object
# Q28_Part_8     531 non-null object
# Q28_Part_9     210 non-null object
# Q28_Part_10    173 non-null object
# Q28_Part_11    131 non-null object
# Q28_Part_12    175 non-null object
# Q28_Part_13    433 non-null object
# Q28_Part_14    487 non-null object
# Q28_Part_15    666 non-null object
# Q28_Part_16    251 non-null object
# Q28_Part_17    284 non-null object
# Q28_Part_18    85 non-null object
# Q28_Part_19    859 non-null object
# Q28_Part_20    224 non-null object
# Q28_Part_21    625 non-null object
# Q28_Part_22    18 non-null object
# Q28_Part_23    120 non-null object
# Q28_Part_24    32 non-null object
# ...

# %% [markdown]
# From the visual and programmatic analysis:
# * There are rows with missing data, but deviating from data we explored till now, missing information is expected per record as selections are optional. We will melt into one single column removing missing values, and use this column for analysis.
# * All columns are loaded with the correct data type.
# * Row with ID 0, is the same as the question. We will drop this row from the analysis as it does not have any empirical value.
# * Column names are not informative, we will rename columns with more informative names.

# %%
mlProductsDF.drop([0],inplace=True)
mlProductsDF.reset_index(drop=True,inplace=True)

# %%
mlProductsDF.head()
# Out:
#   Q28_Part_1 Q28_Part_2 Q28_Part_3 Q28_Part_4 Q28_Part_5 Q28_Part_6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Q28_Part_7                    Q28_Part_8 Q28_Part_9 Q28_Part_10     ...      \
# 0        NaN                           NaN        NaN         NaN     ...
# 1        NaN                           NaN        NaN         NaN     ...
# 2        NaN                           NaN        NaN         NaN     ...
# 3        NaN                           NaN        NaN         NaN     ...
# 4        NaN  Google Cloud Translation API        NaN         NaN     ...
#
#   Q28_Part_34 Q28_Part_35 Q28_Part_36 Q28_Part_37 Q28_Part_38 Q28_Part_39  \
# ...

# %%
mlProductsDF = pd.melt(mlProductsDF)

# %%
mlProductsDF.head()
# Out:
#      variable value
# 0  Q28_Part_1   NaN
# 1  Q28_Part_1   NaN
# 2  Q28_Part_1   NaN
# 3  Q28_Part_1   NaN
# 4  Q28_Part_1   NaN

# %%
mlProductsDF.drop(columns=['variable'],inplace=True)
mlProductsDF.dropna(inplace=True)
mlProductsDF.reset_index(drop=True,inplace=True)

# %%
mlProductsDF.head()
# Out:
#                value
# 0  Amazon Transcribe
# 1  Amazon Transcribe
# 2  Amazon Transcribe
# 3  Amazon Transcribe
# 4  Amazon Transcribe

# %%
mlProductsDF.rename(columns={'value':'mlProducts'},inplace=True)

# %%
generate_horizontal_countplot(y=mlProductsDF.mlProducts,
                             ylabel = 'ML Products',
                             figName = 'mlProducts.jpeg')

# %% [markdown]
# We will persist the clean copy of the dataframe as a CSV file.
#
# We no longer need "mlProductsDF" in the analysis. We will clean up from memory.

# %%
mlProductsDF.to_csv('mlProducts.csv',index=False)

# %%
del mlProductsDF
gc.collect()
# Out:
# 7299

# %% [markdown]
# ### Which of the following relational database products have you used at work or school in the last 5 years?
# * __AWS Relational Database Service__
# * __AWS Aurora__
# * __Google Cloud SQL__
# * __Google Cloud Spanner__
# * __AWS DynamoDB__
# * __Google Cloud Datastore__
# * __Google Cloud Bigtable__
# * __AWS SimpleDB__
# * __Microsoft SQL Server__
# * __MySQL__
# * __PostgresSQL__
# * __SQLite__
# * __Oracle Database__
# * __Ingres__
# * __Microsoft Access__
# * __NexusDB__
# * __SAP IQ__
# * __Google Fusion Tables__
# * __Azure Database for MySQL__
# * __Azure Cosmos DB__
# * __Azure SQL Database__
# * __Azure Database for PostgreSQL__
# * __IBM Cloud Compose__
# * __IBM Cloud Compose for MySQL__
# * __IBM Cloud Compose for PostgreSQL__
# * __IBM Cloud Db2__
# * __None__
# * __Other__

# %%
rdbmsDF = multipleChoiceDF[['Q29_Part_1', 'Q29_Part_2','Q29_Part_3', 'Q29_Part_4','Q29_Part_5', 'Q29_Part_6',
                            'Q29_Part_7','Q29_Part_8','Q29_Part_9','Q29_Part_10','Q29_Part_11','Q29_Part_12',
                            'Q29_Part_13','Q29_Part_14','Q29_Part_15','Q29_Part_16','Q29_Part_17','Q29_Part_18',
                            'Q29_Part_19','Q29_Part_20','Q29_Part_21', 'Q29_Part_22','Q29_Part_23', 'Q29_Part_24',
                            'Q29_Part_25', 'Q29_Part_26','Q29_Part_27','Q29_Part_28']]

# %%
rdbmsDF.head()
# Out:
#                                           Q29_Part_1  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q29_Part_2  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q29_Part_3  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
rdbmsDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23860 entries, 0 to 23859
# Data columns (total 28 columns):
# Q29_Part_1     899 non-null object
# Q29_Part_2     315 non-null object
# Q29_Part_3     616 non-null object
# Q29_Part_4     104 non-null object
# Q29_Part_5     731 non-null object
# Q29_Part_6     516 non-null object
# Q29_Part_7     514 non-null object
# Q29_Part_8     200 non-null object
# Q29_Part_9     3125 non-null object
# Q29_Part_10    6189 non-null object
# Q29_Part_11    3853 non-null object
# Q29_Part_12    3730 non-null object
# Q29_Part_13    2416 non-null object
# Q29_Part_14    60 non-null object
# Q29_Part_15    1355 non-null object
# Q29_Part_16    39 non-null object
# Q29_Part_17    72 non-null object
# Q29_Part_18    121 non-null object
# Q29_Part_19    253 non-null object
# Q29_Part_20    214 non-null object
# Q29_Part_21    669 non-null object
# Q29_Part_22    138 non-null object
# Q29_Part_23    67 non-null object
# ...

# %% [markdown]
# From the visual and programmatic analysis:
# * There are rows with missing data, but deviating from data we explored till now, missing information is expected per record as selections are optional. We will melt into one single column removing missing values, and use this column for analysis.
# * All columns are loaded with the correct data type.
# * Row with ID 0, is the same as the question. We will drop this row from the analysis as it does not have any empirical value.
# * Column names are not informative, we will rename columns with more informative names.

# %%
rdbmsDF.drop([0],inplace=True)
rdbmsDF.reset_index(drop=True,inplace=True)

# %%
rdbmsDF.head()
# Out:
#   Q29_Part_1 Q29_Part_2 Q29_Part_3 Q29_Part_4 Q29_Part_5 Q29_Part_6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Q29_Part_7 Q29_Part_8 Q29_Part_9 Q29_Part_10     ...     Q29_Part_19  \
# 0        NaN        NaN        NaN         NaN     ...             NaN
# 1        NaN        NaN        NaN         NaN     ...             NaN
# 2        NaN        NaN        NaN         NaN     ...             NaN
# 3        NaN        NaN        NaN         NaN     ...             NaN
# 4        NaN        NaN        NaN         NaN     ...             NaN
#
#   Q29_Part_20 Q29_Part_21 Q29_Part_22        Q29_Part_23 Q29_Part_24  \
# ...

# %%
rdbmsDF = pd.melt(rdbmsDF)

# %%
rdbmsDF.head()
# Out:
#      variable value
# 0  Q29_Part_1   NaN
# 1  Q29_Part_1   NaN
# 2  Q29_Part_1   NaN
# 3  Q29_Part_1   NaN
# 4  Q29_Part_1   NaN

# %%
rdbmsDF.drop(columns=['variable'],inplace=True)
rdbmsDF.dropna(inplace=True)
rdbmsDF.reset_index(drop=True,inplace=True)

# %%
rdbmsDF.rename(columns={'value':'rdbms'},inplace=True)

# %%
generate_horizontal_countplot(y=rdbmsDF.rdbms,
                             ylabel = 'RDBMS Products',
                             figName = 'rdbmsProducts.jpeg')

# %% [markdown]
# We will persist the clean copy of the dataframe as a CSV file.
#
# We no longer need "rdbmsDF" in the analysis. We will clean up from memory.

# %%
rdbmsDF.to_csv('rdbms.csv',index=False)

# %%
del rdbmsDF
gc.collect()
# Out:
# 5016

# %% [markdown]
# ### Which of the following big data and analytics products have you used at work or school in the last 5 years?
#
# * __AWS Elastic MapReduce__
# * __AWS Batch__
# * __Google Cloud Dataproc__
# * __Google Cloud Dataflow__
# * __Google Cloud Dataprep__
# * __AWS Kinesis__
# * __Google Cloud Pub/Sub__
# * __AWS Athena__
# * __AWS Redshift__
# * __Google BigQuery__
# * __Teradata__
# * __Microsoft Analysis Services__
# * __Oracle Exadata__
# * __Oracle Warehouse Builder__
# * __SAP IQ__
# * __Snowflake__
# * __Databricks__
# * __Azure SQL Data Warehouse__
# * __Azure HDInsight__
# * __Azure Stream Analytics__
# * __IBM InfoSphere DataStorage__
# * __IBM Cloud Analytics Engine__
# * __IBM Cloud Streaming Analytics__
# * __None__
# * __Other__

# %%
bigDataAnalytcsDF = multipleChoiceDF[['Q30_Part_1', 'Q30_Part_2','Q30_Part_3', 'Q30_Part_4','Q30_Part_5', 
                                      'Q30_Part_6','Q30_Part_7','Q30_Part_8','Q30_Part_9','Q30_Part_10',
                                      'Q30_Part_11','Q30_Part_12','Q30_Part_13','Q30_Part_14','Q30_Part_15',
                                      'Q30_Part_16','Q30_Part_17','Q30_Part_18','Q30_Part_19','Q30_Part_20',
                                      'Q30_Part_21', 'Q30_Part_22','Q30_Part_23', 'Q30_Part_24','Q30_Part_25']]

# %%
bigDataAnalytcsDF.head()
# Out:
#                                           Q30_Part_1  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q30_Part_2  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q30_Part_3  \
# 0  Which of the following big data and analytics ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
bigDataAnalytcsDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23860 entries, 0 to 23859
# Data columns (total 25 columns):
# Q30_Part_1     622 non-null object
# Q30_Part_2     213 non-null object
# Q30_Part_3     238 non-null object
# Q30_Part_4     386 non-null object
# Q30_Part_5     213 non-null object
# Q30_Part_6     335 non-null object
# Q30_Part_7     287 non-null object
# Q30_Part_8     384 non-null object
# Q30_Part_9     943 non-null object
# Q30_Part_10    1206 non-null object
# Q30_Part_11    598 non-null object
# Q30_Part_12    422 non-null object
# Q30_Part_13    212 non-null object
# Q30_Part_14    126 non-null object
# Q30_Part_15    62 non-null object
# Q30_Part_16    240 non-null object
# Q30_Part_17    832 non-null object
# Q30_Part_18    284 non-null object
# Q30_Part_19    240 non-null object
# Q30_Part_20    164 non-null object
# Q30_Part_21    68 non-null object
# Q30_Part_22    142 non-null object
# Q30_Part_23    82 non-null object
# ...

# %% [markdown]
# From the visual and programmatic analysis:
# * There are rows with missing data, but deviating from data we explored till now, missing information is expected per record as selections are optional. We will melt into one single column removing missing values, and use this column for analysis.
# * All columns are loaded with the correct data type.
# * Row with ID 0, is the same as the question. We will drop this row from the analysis as it does not have any empirical value.
# * Column names are not informative, we will rename columns with more informative names.

# %%
bigDataAnalytcsDF.drop([0],inplace=True)
bigDataAnalytcsDF.reset_index(drop=True,inplace=True)

# %%
bigDataAnalytcsDF.head()
# Out:
#   Q30_Part_1 Q30_Part_2 Q30_Part_3             Q30_Part_4 Q30_Part_5  \
# 0        NaN        NaN        NaN                    NaN        NaN
# 1        NaN        NaN        NaN                    NaN        NaN
# 2        NaN        NaN        NaN                    NaN        NaN
# 3        NaN        NaN        NaN                    NaN        NaN
# 4        NaN        NaN        NaN  Google Cloud Dataflow        NaN
#
#   Q30_Part_6 Q30_Part_7 Q30_Part_8 Q30_Part_9 Q30_Part_10     ...      \
# 0        NaN        NaN        NaN        NaN         NaN     ...
# 1        NaN        NaN        NaN        NaN         NaN     ...
# 2        NaN        NaN        NaN        NaN         NaN     ...
# 3        NaN        NaN        NaN        NaN         NaN     ...
# 4        NaN        NaN        NaN        NaN         NaN     ...
#
#   Q30_Part_16 Q30_Part_17 Q30_Part_18 Q30_Part_19 Q30_Part_20 Q30_Part_21  \
# ...

# %%
bigDataAnalytcsDF = pd.melt(bigDataAnalytcsDF)

# %%
bigDataAnalytcsDF.head()
# Out:
#      variable value
# 0  Q30_Part_1   NaN
# 1  Q30_Part_1   NaN
# 2  Q30_Part_1   NaN
# 3  Q30_Part_1   NaN
# 4  Q30_Part_1   NaN

# %%
bigDataAnalytcsDF.drop(columns=['variable'],inplace=True)
bigDataAnalytcsDF.dropna(inplace=True)
bigDataAnalytcsDF.reset_index(drop=True,inplace=True)

# %%
bigDataAnalytcsDF.rename(columns={'value':'bigDataAnalytcs'},inplace=True)

# %%
generate_horizontal_countplot(y=bigDataAnalytcsDF.bigDataAnalytcs,
                             ylabel = 'Big Data Analytcs Products',
                             figName = 'bigDataAnalytcs.jpeg')

# %% [markdown]
# We will persist the clean copy of the dataframe as a CSV file.
#
# We no longer need "bigDataAnalytcsDF" in the analysis. We will clean up from memory.

# %%
bigDataAnalytcsDF.to_csv('bigDataAnalytcs.csv',index=False)

# %%
del bigDataAnalytcsDF
gc.collect()
# Out:
# 4628

# %% [markdown]
# ### Which types of data do you currently interact with most often at work or school?
#
# * __Audio Data__
# * __Categorical Data__
# * __Genetic Data__
# * __Geospatial Data__
# * __Image Data__
# * __Numerical Data__
# * __Sensor Data__
# * __Tabular Data__
# * __Text Data__
# * __Time Series Data__
# * __Video Data__
# * __Other Data__

# %%
dataTypeDF = multipleChoiceDF[['Q31_Part_1', 'Q31_Part_2','Q31_Part_3', 'Q31_Part_4','Q31_Part_5', 'Q31_Part_6',
                               'Q31_Part_7','Q31_Part_8','Q31_Part_9','Q31_Part_10','Q31_Part_11','Q31_Part_12']]

# %%
dataTypeDF.head()
# Out:
#                                           Q31_Part_1  \
# 0  Which types of data do you currently interact ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q31_Part_2  \
# 0  Which types of data do you currently interact ...
# 1                                                NaN
# 2                                                NaN
# 3                                   Categorical Data
# 4                                   Categorical Data
#
#                                           Q31_Part_3  \
# 0  Which types of data do you currently interact ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
dataTypeDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23860 entries, 0 to 23859
# Data columns (total 12 columns):
# Q31_Part_1     954 non-null object
# Q31_Part_2     8150 non-null object
# Q31_Part_3     1055 non-null object
# Q31_Part_4     2246 non-null object
# Q31_Part_5     5388 non-null object
# Q31_Part_6     11025 non-null object
# Q31_Part_7     2553 non-null object
# Q31_Part_8     7395 non-null object
# Q31_Part_9     8730 non-null object
# Q31_Part_10    7780 non-null object
# Q31_Part_11    1384 non-null object
# Q31_Part_12    406 non-null object
# dtypes: object(12)
# memory usage: 2.2+ MB

# %% [markdown]
# From the visual and programmatic analysis:
# * There are rows with missing data, but deviating from data we explored till now, missing information is expected per record as selections are optional. We will melt into one single column removing missing values, and use this column for analysis.
# * All columns are loaded with the correct data type.
# * Row with ID 0, is the same as the question. We will drop this row from the analysis as it does not have any empirical value.
# * Column names are not informative, we will rename columns with more informative names.

# %%
dataTypeDF.drop([0],inplace=True)
dataTypeDF.reset_index(drop=True,inplace=True)

# %%
dataTypeDF = pd.melt(dataTypeDF)

# %%
dataTypeDF.head()
# Out:
#      variable value
# 0  Q31_Part_1   NaN
# 1  Q31_Part_1   NaN
# 2  Q31_Part_1   NaN
# 3  Q31_Part_1   NaN
# 4  Q31_Part_1   NaN

# %%
dataTypeDF.drop(columns=['variable'],inplace=True)
dataTypeDF.dropna(inplace=True)
dataTypeDF.reset_index(drop=True,inplace=True)

# %%
dataTypeDF.rename(columns={'value':'dataType'},inplace=True)

# %%
generate_horizontal_countplot(y=dataTypeDF.dataType,
                             ylabel = 'Data Type',
                             figName = 'dataType.jpeg')

# %% [markdown]
# We will persist the clean copy of the dataframe as a CSV file.
#
# We no longer need "dataTypeDF" in the analysis. We will clean up from memory.

# %%
dataTypeDF.to_csv('dataType.csv',index=False)

# %%
del dataTypeDF
gc.collect()
# Out:
# 3150

# %% [markdown]
# ### What is the type of data that you currently interact with most often at work or school?

# %%
frequentDataTypeDF = pd.DataFrame(multipleChoiceDF.Q32)

# %%
frequentDataTypeDF.head()
# Out:
#                                                  Q32
# 0  What is the type of data that you currently in...
# 1                                                NaN
# 2                                                NaN
# 3                                   Time Series Data
# 4                                     Numerical Data

# %%
frequentDataTypeDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23860 entries, 0 to 23859
# Data columns (total 1 columns):
# Q32    13879 non-null object
# dtypes: object(1)
# memory usage: 186.5+ KB

# %% [markdown]
# From the visual and programmatic analysis:
# * There are rows with missing data, we will not include these records in our report.
# * All columns are loaded with the correct data type.
# * Row with ID 0, is the same as the question. We will drop this row from the analysis as it does not have any empirical value.
# * Column names are not informative, we will rename columns with more informative names.

# %%
frequentDataTypeDF.drop([0],inplace=True)
frequentDataTypeDF.dropna(inplace=True)
frequentDataTypeDF.reset_index(drop=True,inplace=True)

# %%
generate_horizontal_countplot(y=frequentDataTypeDF.Q32,
                             ylabel = 'Frequent Data Type',
                             figName = 'frequentDataType.jpeg')

# %% [markdown]
# We will persist the clean copy of the dataframe as a CSV file.
#
# We no longer need "frequentDataTypeDF" in the analysis. We will clean up from memory.

# %%
frequentDataTypeDF.to_csv('frequentDataType.csv',index=False)

# %%
del frequentDataTypeDF
gc.collect()
# Out:
# 3268

# %% [markdown]
# ### Where do you find public datasets?
#
# * __Government websites__
# * __University research group websites__
# * __Non-profit research group websites__
# * __Dataset aggregator/platform (Socrata, Kaggle Public Datasets Platform, etc.)__
# * __I collect my own data (web-scraping, etc.)__
# * __Publicly released data from private companies__
# * __Google Search__
# * __Google Dataset Search__
# * __GitHub__
# * __None/I do not work with public data__
# * __Other__

# %%
publicDataSetsDF = multipleChoiceDF[['Q33_Part_1', 'Q33_Part_2','Q33_Part_3', 'Q33_Part_4','Q33_Part_5', 'Q33_Part_6',
                                     'Q33_Part_7','Q33_Part_8','Q33_Part_9','Q33_Part_10','Q33_Part_11']]

# %%
publicDataSetsDF.head()
# Out:
#                                           Q33_Part_1  \
# 0  Where do you find public datasets? (Select all...
# 1                                                NaN
# 2                                                NaN
# 3                                Government websites
# 4                                Government websites
#
#                                           Q33_Part_2  \
# 0  Where do you find public datasets? (Select all...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q33_Part_3  \
# 0  Where do you find public datasets? (Select all...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
publicDataSetsDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23860 entries, 0 to 23859
# Data columns (total 11 columns):
# Q33_Part_1     4758 non-null object
# Q33_Part_2     4104 non-null object
# Q33_Part_3     2809 non-null object
# Q33_Part_4     8176 non-null object
# Q33_Part_5     5226 non-null object
# Q33_Part_6     2998 non-null object
# Q33_Part_7     7014 non-null object
# Q33_Part_8     3685 non-null object
# Q33_Part_9     6076 non-null object
# Q33_Part_10    2028 non-null object
# Q33_Part_11    450 non-null object
# dtypes: object(11)
# memory usage: 2.0+ MB

# %% [markdown]
# From the visual and programmatic analysis:
# * There are rows with missing data, but deviating from data we explored till now, missing information is expected per record as selections are optional. We will melt into one single column removing missing values, and use this column for analysis.
# * All columns are loaded with the correct data type.
# * Row with ID 0, is the same as the question. We will drop this row from the analysis as it does not have any empirical value.
# * Column names are not informative, we will rename columns with more informative names.

# %%
publicDataSetsDF.drop([0],inplace=True)
publicDataSetsDF.reset_index(drop=True,inplace=True)

# %%
publicDataSetsDF = pd.melt(publicDataSetsDF)

# %%
publicDataSetsDF.head()
# Out:
#      variable                value
# 0  Q33_Part_1                  NaN
# 1  Q33_Part_1                  NaN
# 2  Q33_Part_1  Government websites
# 3  Q33_Part_1  Government websites
# 4  Q33_Part_1                  NaN

# %%
publicDataSetsDF.drop(columns=['variable'],inplace=True)
publicDataSetsDF.dropna(inplace=True)
publicDataSetsDF.reset_index(drop=True,inplace=True)

# %%
publicDataSetsDF.rename(columns={'value':'publicDataSets'},inplace=True)

# %%
generate_horizontal_countplot(y=publicDataSetsDF.publicDataSets,
                             ylabel = 'Public Data Sets',
                             figName = 'publicDataSets.jpeg')

# %% [markdown]
# We will persist the clean copy of the dataframe as a CSV file.
#
# We no longer need "publicDataSetsDF" in the analysis. We will clean up from memory.

# %%
publicDataSetsDF.to_csv('publicDataSets.csv',index=False)

# %%
del publicDataSetsDF
gc.collect()
# Out:
# 3241

# %% [markdown]
# ### During a typical data science project at work or school, approximately what proportion of your time is devoted to the following?
#
# * __Gathering data__
# * __Cleaning data__
# * __Visualizing data__
# * __Model building/model selection__
# * __Putting the model into production__
# * __Finding insights in the data and communicating with stakeholders__

# %%
dataScienceActivityDF = multipleChoiceDF[['Q34_Part_1', 'Q34_Part_2','Q34_Part_3', 'Q34_Part_4','Q34_Part_5',
                                          'Q34_Part_6']]

# %%
dataScienceActivityDF.head()
# Out:
#                                           Q34_Part_1  \
# 0  During a typical data science project at work ...
# 1                                                NaN
# 2                                                NaN
# 3                                                  2
# 4                                                 20
#
#                                           Q34_Part_2  \
# 0  During a typical data science project at work ...
# 1                                                NaN
# 2                                                NaN
# 3                                                  3
# 4                                                 25
#
#                                           Q34_Part_3  \
# 0  During a typical data science project at work ...
# 1                                                NaN
# 2                                                NaN
# 3                                                 20
# ...

# %%
dataScienceActivityDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23860 entries, 0 to 23859
# Data columns (total 6 columns):
# Q34_Part_1    15938 non-null object
# Q34_Part_2    15938 non-null object
# Q34_Part_3    15938 non-null object
# Q34_Part_4    15938 non-null object
# Q34_Part_5    15938 non-null object
# Q34_Part_6    15938 non-null object
# dtypes: object(6)
# memory usage: 1.1+ MB

# %% [markdown]
# From the visual and programmatic analysis:
# * There are rows with missing data, but deviating from data we explored till now, missing information is expected per record as selections are optional. We will melt into one single column removing missing values, and use this column for analysis.
# * All columns are loaded with the correct data type.
# * Row with ID 0, is the same as the question. We will drop this row from the analysis as it does not have any empirical value.
# * Column names are not informative, we will rename columns with more informative names.

# %%
dataScienceActivityDF.drop([0],inplace=True)
dataScienceActivityDF.reset_index(drop=True,inplace=True)

# %%
dataScienceActivityDF.rename(columns={"Q34_Part_1":"Gathering data",
                                 "Q34_Part_2":"Cleaning data",
                                 "Q34_Part_3":"Visualizing data",
                                 "Q34_Part_4":"Model building/model selection",
                                 "Q34_Part_5":"Putting the model into production",
                                 "Q34_Part_6":"Finding insights in the data and communicating with stakeholders"},
                        inplace = True)

# %%
dataScienceActivityDF = pd.melt(dataScienceActivityDF)

# %%
dataScienceActivityDF.head()
# Out:
#          variable value
# 0  Gathering data   NaN
# 1  Gathering data   NaN
# 2  Gathering data     2
# 3  Gathering data    20
# 4  Gathering data    10

# %%
dataScienceActivityDF.rename(columns={"variable":"Data-Science-Activity"},inplace=True)

# %%
dataScienceActivityDF.sort_values("Data-Science-Activity",inplace=True)
dataScienceActivityDF.reset_index(drop=True,inplace=True)

# %%
dataScienceActivityDF.dropna(inplace=True)
dataScienceActivityDF.reset_index(drop=True,inplace=True)

# %%
dataScienceActivityDF['value']=dataScienceActivityDF.value.astype(float)

# %%
generate_bar_plot(data=dataScienceActivityDF,
                  x="Data-Science-Activity",
                  y="value",
                  xlabel="Data Science Activity",
                  figName="Data Science Activity_Distribution.jpeg",
                  figSize=(18, 15))

# %% [markdown]
# We will persist the clean copy of the dataframe as a CSV file.
#
# We no longer need "dataScienceActivityDF" in the analysis. We will clean up from memory.

# %%
dataScienceActivityDF.to_csv('dataScienceActivity.csv',index=False)

# %%
del dataScienceActivityDF
gc.collect()
# Out:
# 2852

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this notebook, we have analyzed various technical tools and utilities that are used in Machine learning and Data science projects.
